# %%
import pandas as pd

# %%
sales = pd.read_csv(r'/Users/mac/Documents/DATA ANALYSIS/PYTHON/sales_data.csv')

# %%
sales
# Out:
#     Order ID           Order Date Customer ID Region Product Category  \
# 0    ORD1000  2025-01-06 00:00:00      CUST26  North             Home
# 1    ORD1001  2025-02-12 00:00:00      CUST17  South         Clothing
# 2    ORD1002  2025-05-29 00:00:00      CUST41  South      Electronics
# 3    ORD1003  2025-05-20 00:00:00      CUST19  South      Electronics
# 4    ORD1004  2025-03-18 00:00:00      CUST35  North             Home
# ..       ...                  ...         ...    ...              ...
# 195  ORD1195  2025-04-15 00:00:00      CUST22   West             Home
# 196  ORD1196  2025-05-27 00:00:00       CUST5  North         Clothing
# 197  ORD1197  2025-01-23 00:00:00       CUST4   East      Electronics
# 198  ORD1198  2025-06-01 00:00:00      CUST11  South         Clothing
# 199  ORD1199  2025-02-02 00:00:00      CUST30  North      Electronics
#
#      Product Name  Quantity Ordered  Price Each    Sales
# 0          Jacket                 7       77.39   541.73
# ...

# %% [markdown]
# 1. How many unique products were sold?

# %%
sales['Product Name'].nunique()
# Out:
# 10

# %% [markdown]
# 2. What is the total sales per region?

# %%
sales.head(2)
# Out:
#   Order ID           Order Date Customer ID Region Product Category  \
# 0  ORD1000  2025-01-06 00:00:00      CUST26  North             Home
# 1  ORD1001  2025-02-12 00:00:00      CUST17  South         Clothing
#
#   Product Name  Quantity Ordered  Price Each   Sales
# 0       Jacket                 7       77.39  541.73
# 1        Jeans                 4      177.12  708.48

# %%
sales.groupby('Region')['Sales'].sum()
# Out:
# Region
# East     62742.94
# North    69957.31
# South    66469.41
# West     63016.53
# Name: Sales, dtype: float64

# %% [markdown]
# 3. Which product category had the highest total sales?

# %%
sales.groupby('Product Category')['Sales'].sum().sort_values(ascending=False).head(1)
# Out:
# Product Category
# Toys    72871.63
# Name: Sales, dtype: float64

# %% [markdown]
# 4. What is the average quantity ordered per order?

# %%
sales.head(2)
# Out:
#   Order ID           Order Date Customer ID Region Product Category  \
# 0  ORD1000  2025-01-06 00:00:00      CUST26  North             Home
# 1  ORD1001  2025-02-12 00:00:00      CUST17  South         Clothing
#
#   Product Name  Quantity Ordered  Price Each   Sales
# 0       Jacket                 7       77.39  541.73
# 1        Jeans                 4      177.12  708.48

# %%
sales['Quantity Ordered'].mean()
# Out:
# np.float64(5.07)

# %% [markdown]
# 5. Find all orders placed in March 2025.

# %%
sales['Order Date'] = pd.to_datetime(sales['Order Date'])

# %%
sales[sales['Order Date'].dt.month == 3]
# Out:
#     Order ID Order Date Customer ID Region Product Category   Product Name  \
# 4    ORD1004 2025-03-18      CUST35  North             Home     Smartphone
# 20   ORD1020 2025-03-04      CUST27   West      Electronics          Shirt
# 22   ORD1022 2025-03-31      CUST12  South             Home  Action Figure
# 27   ORD1027 2025-03-11      CUST29   West             Home          Jeans
# 41   ORD1041 2025-03-21       CUST7   East             Toys         Jacket
# 46   ORD1046 2025-03-26      CUST47  North             Home           Sofa
# 55   ORD1055 2025-03-09      CUST42  South         Clothing   Dining Table
# 56   ORD1056 2025-03-05       CUST6  North             Toys          Jeans
# 58   ORD1058 2025-03-06       CUST8   West             Home     Smartphone
# 63   ORD1063 2025-03-28      CUST45  South             Toys         Laptop
# 64   ORD1064 2025-03-14      CUST17   West      Electronics   Dining Table
# ...

# %% [markdown]
# 6. What is the monthly sales trend?

# %%
sales.head(2)
# Out:
#   Order ID Order Date Customer ID Region Product Category Product Name  \
# 0  ORD1000 2025-01-06      CUST26  North             Home       Jacket
# 1  ORD1001 2025-02-12      CUST17  South         Clothing        Jeans
#
#    Quantity Ordered  Price Each   Sales
# 0                 7       77.39  541.73
# 1                 4      177.12  708.48

# %%
sales.groupby(sales['Order Date'].dt.to_period('M'))['Sales'].sum()
# Out:
# Order Date
# 2025-01    44243.39
# 2025-02    42422.43
# 2025-03    43104.40
# 2025-04    44839.59
# 2025-05    37907.62
# 2025-06    49668.76
# Freq: M, Name: Sales, dtype: float64

# %% [markdown]
#  Which customer had the highest total purchase amount?

# %%
sales.head(2)
# Out:
#   Order ID Order Date Customer ID Region Product Category Product Name  \
# 0  ORD1000 2025-01-06      CUST26  North             Home       Jacket
# 1  ORD1001 2025-02-12      CUST17  South         Clothing        Jeans
#
#    Quantity Ordered  Price Each   Sales
# 0                 7       77.39  541.73
# 1                 4      177.12  708.48

# %%
sales.groupby('Customer ID')['Sales'].sum().sort_values(ascending=False).head(1)
# Out:
# Customer ID
# CUST41    18679.61
# Name: Sales, dtype: float64

# %% [markdown]
# 8. Add a new column for total cost per order (Sales = Quantity × Price Each).

# %%
sales['total sales'] = sales['Quantity Ordered'] * sales['Price Each']

# %%
sales.head(2)
# Out:
#   Order ID Order Date Customer ID Region Product Category Product Name  \
# 0  ORD1000 2025-01-06      CUST26  North             Home       Jacket
# 1  ORD1001 2025-02-12      CUST17  South         Clothing        Jeans
#
#    Quantity Ordered  Price Each   Sales  total sales
# 0                 7       77.39  541.73       541.73
# 1                 4      177.12  708.48       708.48

# %% [markdown]
# 9. Check for any missing data.

# %%
sales.isnull()
# Out:
#      Order ID  Order Date  Customer ID  Region  Product Category  \
# 0       False       False        False   False             False
# 1       False       False        False   False             False
# 2       False       False        False   False             False
# 3       False       False        False   False             False
# 4       False       False        False   False             False
# ..        ...         ...          ...     ...               ...
# 195     False       False        False   False             False
# 196     False       False        False   False             False
# 197     False       False        False   False             False
# 198     False       False        False   False             False
# 199     False       False        False   False             False
#
#      Product Name  Quantity Ordered  Price Each  Sales  total sales
# 0           False             False       False  False        False
# ...

# %% [markdown]
# 10. What are the top 5 most sold products by quantity?

# %%
sales.groupby('Product Name')['Quantity Ordered'].sum().sort_values(ascending=False).head(5)
# Out:
# Product Name
# Doll             122
# Action Figure    117
# Microwave        111
# Shirt            106
# Smartphone       106
# Name: Quantity Ordered, dtype: int64

# %% [markdown]
# 11. Which region had the highest average sale per order?

# %%
sales.head(2)
# Out:
#   Order ID Order Date Customer ID Region Product Category Product Name  \
# 0  ORD1000 2025-01-06      CUST26  North             Home       Jacket
# 1  ORD1001 2025-02-12      CUST17  South         Clothing        Jeans
#
#    Quantity Ordered  Price Each   Sales  total sales
# 0                 7       77.39  541.73       541.73
# 1                 4      177.12  708.48       708.48

# %%
sales.groupby('Region')['Sales'].mean()
# Out:
# Region
# East     1459.138140
# North    1227.321228
# South    1329.388200
# West     1260.330600
# Name: Sales, dtype: float64

# %% [markdown]
# 12. Find the number of orders made per month.

# %%
sales['Order Month'] = sales['Order Date'].dt.month

# %%
sales.head(2)
# Out:
#   Order ID Order Date Customer ID Region Product Category Product Name  \
# 0  ORD1000 2025-01-06      CUST26  North             Home       Jacket
# 1  ORD1001 2025-02-12      CUST17  South         Clothing        Jeans
#
#    Quantity Ordered  Price Each   Sales  total sales  Order Month
# 0                 7       77.39  541.73       541.73            1
# 1                 4      177.12  708.48       708.48            2

# %%
sales.groupby('Order Month')['Order ID'].nunique()
# Out:
# Order Month
# 1    37
# 2    30
# 3    32
# 4    36
# 5    34
# 6    31
# Name: Order ID, dtype: int64

# %% [markdown]
# 13. Which product has the highest price?

# %%
sales.head(2)
# Out:
#   Order ID Order Date Customer ID Region Product Category Product Name  \
# 0  ORD1000 2025-01-06      CUST26  North             Home       Jacket
# 1  ORD1001 2025-02-12      CUST17  South         Clothing        Jeans
#
#    Quantity Ordered  Price Each   Sales  total sales  Order Month
# 0                 7       77.39  541.73       541.73            1
# 1                 4      177.12  708.48       708.48            2

# %%
sales.groupby('Product Name')['Price Each'].sum().sort_values(ascending=False).head(1)
# Out:
# Product Name
# Laptop    5753.21
# Name: Price Each, dtype: float64

# %% [markdown]
# 14. What is the most common order quantity?

# %%
sales['Quantity Ordered'].mode()
# Out:
# 0    7
# Name: Quantity Ordered, dtype: int64

# %% [markdown]
# 15. Get the daily average sales.

# %%
sales.groupby(sales['Order Date'].dt.date)['Sales'].mean()
# Out:
# Order Date
# 2025-01-01    1923.920000
# 2025-01-03     675.600000
# 2025-01-04    2707.200000
# 2025-01-05     354.790000
# 2025-01-06     767.283333
#                  ...
# 2025-06-22     837.360000
# 2025-06-24    2412.210000
# 2025-06-28    2106.180000
# 2025-06-29    4300.920000
# 2025-06-30    1141.280000
# Name: Sales, Length: 123, dtype: float64
